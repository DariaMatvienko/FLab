# %% [markdown]
# <a href="https://colab.research.google.com/github/DariaMatvienko/FLab/blob/main/SL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание 1
# Реализовать kmeans
# Визуализировать сходимость центров кластеров
# Оценить $SSE$ для значений $k = 1, \ldots, 10$ и построить график зависимости $SSE$ от количества кластеров.
# Алгоритм к-средних:
# На вход алгоритм получает матрицу данных $D$, количество кластеров $k$, и критерий остановки $\epsilon$:
#
# -- t = 0
# -- случайным образом инициализируем $k$ центров кластеров: $\mu_1^t, \mu_2^t, \ldots, \mu_k^t \in R^d$;
# -- повторять:
# *  $t = t + 1$;
# * $C_j = 0$ для всех $j = 1, \ldots, k$
# * для каждого $x_j \in D$
# $j^* = arg\min\limits_C \{||X_j - \mu_i^{t-1}||^2\}$
# * присваиваем $x_j$ к ближайшему центру
# $C_{j^*} = C_{j^*} \cup {x_j}$
# * для каждого i=1 до k
# $\mu_i = \frac{1}{|C_i|} \sum\limits_{x_j \in C_i} x_j$
#
# -- пока $\sum_{i=1}^k ||\mu_i^{t} - \mu_i^{t-1}||^2 \leq \epsilon$

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
X, Y = make_blobs(n_samples = 1000, n_features=2, centers=5, cluster_std = 1.2, random_state=17)
plt.scatter(X[:,0], X[:,1])

# %%
import math
import numpy as np
def km(Xj,k,e):
  t=0
  mu=[]
  for n=1 in range(k):
    mu[n]=random.choice(Xj) #k случайные
  Cj=np.zeros(k)
  while ((sum(pow(norm(pow(mu,t)-pow(mu,t-1))),2))<=e):
    t=t+1
    Cj=0 #количество точек в кластере, центроиды
    for d in range (Xj):
      J=np.argmin(pow(norm(Xj[d]-pow(mu,t-1)),2)#метки, объект-центроид
    for j=1 in range(k):
      Cjz=Cjz.union(Xj[d])
    for i=1 in range():
      mu[i]=1/abs(C[i])*sum(Xj[])#серднее арифметическое
# Out:
#   File "<ipython-input-3-4f741f87b6f1>", line 6
#     for n=1 in range(k):
#          ^
# SyntaxError: invalid syntax

# %%
import math
import numpy as np
import operator
def km(Xj,k,e):
  t=0
  #mu = np.empty(Xj.shape[0], dtype=np.intp)
  #mu=np.zeros((k,2))
  #mu=[0] * Xj
  Cj=[] 
  mu=[]
  for i in range (k):
    Cj.append([0]*1)
    mu.append([0]*1)
  for n in range(k):
    ind=np.random.choice(Xj.shape[0]) #k случайные
    mu[n].append(Xj[ind])
    #Cj[n]=np.append(0)#для точек кластера

  while True:
    t=t+1    
    for d in range(Xj.shape[0]):
      dist=[]
      for ii in range(k):
        dist.append(np.power(np.linalg.norm(Xj[d]-mu[ii][len(mu)]),2))
      J=np.argmin(dist)#метки, объект-центроид
      Cj[J].append(Xj[d])#сохраняем точки в кластере
    s=[]
    for sr in range(k):
      mu[sr].append(1/(len(Cj[sr]))*sum(Xj))#среднее арифметическое 
      #u=map(operator.sub,(mu[sr][len(mu[sr])-2]),(mu[sr][len(mu[sr]-1)]))
      #print(np.linalg.norm(mu[sr][len(mu[sr])-2]-mu[sr][len(mu[sr])-1]))
      #print('Разность=', [x-y for x,y in zip((mu[sr][len(mu[sr])-2]),(mu[sr][len(mu[sr]-1)]))])
      #print('Разность=',np.array(mu[sr][len(mu[sr])-2])-np.array(mu[sr][len(mu[sr]-1)]))
      s.append(np.power(np.linalg.norm(mu[sr][len(mu[sr])-2]-mu[sr][len(mu[sr])-1]),2))
  
    #SSE
    sse=0
    norma=[]
  
    for i in range(k):
      for cj in range(len(Cj[i])):
        
        norma.append(np.power(np.linalg.norm(Cj[i][cj]-mu[i][len(mu)]),2))
      sse+=sum(norma)
      print(norma)
    if (sum(s)<=e): 
      Cj.clear()
      mu.clear()
      dist.clear()
      break;
    #if (t==1):break;

  return Cj,sse

# %%
C=[]
K=list(range(1, 11))
#C=km(X,K,E)
plt.figure(figsize=(12,12))
#color = list(np.random.choice(range(256), size=len(K)))
for kol in K:
  k_m,sse=km(X,kol,0.05)
  print(sse)
  plt.subplot(3,2,kol)
  
  plt.scatter(X[:,0],X[:,1],c=color)
  #for i in k_m:
  #  plt.scatter(X[i , 0] , X[i , 1],c=)
  
  plt.title('Количество кластеров=%i' %kol)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 10252
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-7ee98b770530> in <module>()
# ...

# %% [markdown]
# Оценка SSE
# $$ SSE(C) = \sum \limits_{i=1}^{k} \sum \limits_{x_j \in C_i} ||x_j - \mu_i||^2 $$

# %% [markdown]
# Задание 2
# Исследуйте данные с помощью pandas. Посмотрите на признаки и их распределения. (Например, постройте график распределения автомобилей по годам, типу топлива и т.д.)
# Кластеризуйте данные с помощью KMeans из sklearn.clustering. Найдите оптимальное число кластеров
# Произведите анализ получившихся кластеров:
# Пример: первый кластер содержит полноприводные автомобили немецкого производства с АКПП, небольшим пробегом и высокой стоимостью, второй - японцы с правым рулём ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive 
drive.mount('/content/gdrive')

df = pd.read_csv('gdrive/MyDrive/2.csv', encoding='cp1251')
df = df.drop(columns=['Модель', 'Цвет'])
df.head()
# Out:
# Mounted at /content/gdrive
#         Марка     Год Состояние  ...   Руль  Хозяев в ПТС      Цена
# 0  Volkswagen  2013.0        БУ  ...  левый    1 владелец  689196.0
# 1       Skoda  2012.0        БУ  ...  левый    1 владелец  639196.0
# 2     Renault  2015.0        БУ  ...  левый    1 владелец  629196.0
# 3      Nissan  2012.0        БУ  ...  левый    1 владелец  479196.0
# 4         УАЗ  2014.0        БУ  ...  левый    1 владелец  599196.0
#
# [5 rows x 13 columns]

# %%
for col in df.columns:
  sns.displot(df[col])
  plt.title(col)

# %%
#стандартизация
from sklearn.preprocessing import StandardScaler 
ss = StandardScaler() 
new_df=df
new_df[['Год', 'Пробег', 'Объем', 'Мощность', 'Цена']] = ss.fit_transform(new_df[['Год', 'Пробег', 'Объем', 'Мощность', 'Цена']]) 
new_df.head()
# Out:
#         Марка       Год Состояние  ...   Руль  Хозяев в ПТС      Цена
# 0  Volkswagen  1.055883        БУ  ...  левый    1 владелец  0.420103
# 1       Skoda  0.868335        БУ  ...  левый    1 владелец  0.315187
# 2     Renault  1.430978        БУ  ...  левый    1 владелец  0.294203
# 3      Nissan  0.868335        БУ  ...  левый    1 владелец -0.020546
# 4         УАЗ  1.243431        БУ  ...  левый    1 владелец  0.231254
#
# [5 rows x 13 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
#Марка, Состояние, Топливо, Кузов, Привод, КПП, Руль, Хозяев в ПТС
new = OneHotEncoder()
#new.fit(new_df[['Марка','Состояние','Топливо', 'Кузов', 'Привод','КПП','Руль','Хозяев в ПТС']])
new_df=new.fit_transform(new_df[['Марка',1], ['Состояние', 2],['Топливо', 3], ['Кузов', 4],['Привод', 5], ['КПП', 6],['Руль', 7], ['Хозяев в ПТС', 8]]).toarray()
#new.fit_transform(new_df[['Марка','Состояние','Топливо', 'Кузов', 'Привод','КПП','Руль','Хозяев в ПТС']]).toarray())
#new_df = new.fit_transform(new_df[['Марка','Состояние','Топливо', 'Кузов', 'Привод','КПП','Руль','Хозяев в ПТС']])# X head
#new_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-309a86dc4106> in <module>()
#       3 new = OneHotEncoder()
#       4 #new.fit(new_df[['Марка','Состояние','Топливо', 'Кузов', 'Привод','КПП','Руль','Хозяев в ПТС']])
# ----> 5 new_df=new.fit_transform(new_df[['Марка',1], ['Состояние', 2],['Топливо', 3], ['Кузов', 4],['Привод', 5], ['КПП', 6],['Руль', 7], ['Хозяев в ПТС', 8]]).toarray()
#       6 #new.fit_transform(new_df[['Марка','Состояние','Топливо', 'Кузов', 'Привод','КПП','Руль','Хозяев в ПТС']]).toarray())
#       7 #new_df = new.fit_transform(new_df[['Марка','Состояние','Топливо', 'Кузов', 'Привод','КПП','Руль','Хозяев в ПТС']])# X head
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# ...

# %%
from sklearn.cluster import KMeans
K=list(range(1, 11))
X=new_df
plt.figure(figsize=(12,12))
for k in range(1,3):
  kmeans = KMeans(n_clusters=k, random_state=0).fit(X)
  cluster=kmeans
  plt.subplot(3,2,k)
  link=linkage(new_df, 'ward', 'euclidean')
  dn=dendrogram(link)
  #plt.scatter(X[:,0],X[:,1],c=cluster.labels_.astype(float))
  #plt.title('Количество кластеров=',k)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-9934773d5a4a> in <module>()
#       4 plt.figure(figsize=(12,12))
#       5 for k in range(1,3):
# ----> 6   kmeans = KMeans(n_clusters=k, random_state=0).fit(X)
#       7   cluster=kmeans
#       8   plt.subplot(3,2,k)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     857         order = "C" if self.copy_x else None
#     858         X = check_array(X, accept_sparse='csr', dtype=[np.float64, np.float32],
# --> 859                         order=order, copy=self.copy_x)
#     860         # verify that the number of samples given is larger than k
#     861         if _num_samples(X) < self.n_clusters:
#
# ...
